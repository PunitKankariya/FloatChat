# %%
from langchain_google_genai import ChatGoogleGenerativeAI, GoogleGenerativeAIEmbeddings
from langchain_core.messages import SystemMessage, HumanMessage

from dotenv import load_dotenv
import os

load_dotenv()
print(os.getenv("GOOGLE_API_KEY"))
# Out:
# AIzaSyAeJdtCbIxeecZQzpFMMfb526YmJCnCmOk

# %%
print(load_dotenv())
# Out:
# True

# %%
client = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash",
    google_api_key=os.getenv("GOOGLE_API_KEY")
)
client
# Out:
# ChatGoogleGenerativeAI(model='models/gemini-1.5-flash', google_api_key=SecretStr('**********'), client=<google.ai.generativelanguage_v1beta.services.generative_service.client.GenerativeServiceClient object at 0x0000020A304DC190>, default_metadata=())

# %% [markdown]
# ### Test GPT model

# %%
messages = [
    SystemMessage(content="You are a comedian chatbot"),
    HumanMessage(content="hello")
]

# Invoke the Gemini model
response = client.invoke(messages)

# %% [markdown]
# ### Test embedding model

# %%
embeddings_client = GoogleGenerativeAIEmbeddings(
    model="models/embedding-001",
    google_api_key=os.getenv("GOOGLE_API_KEY")
)

response = embeddings_client.embed_query("hello")
# Out:
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# File c:\just be there\hackathon\FloatChat\.venv\Lib\site-packages\langchain_google_genai\embeddings.py:227, in GoogleGenerativeAIEmbeddings.embed_documents(self, texts, batch_size, task_type, titles, output_dimensionality)
#     226 try:
# --> 227     result = self.client.batch_embed_contents(
#     228         BatchEmbedContentsRequest(requests=requests, model=self.model)
#     229     )
#     230 except Exception as e:
#
# File c:\just be there\hackathon\FloatChat\.venv\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:1392, in GenerativeServiceClient.batch_embed_contents(self, request, model, requests, retry, timeout, metadata)
#    1391 # Send the request.
# -> 1392 response = rpc(
#    1393     request,
#    1394     retry=retry,
#    1395     timeout=timeout,
# ...

# %%
embedding = embeddings_client.embed_query("hello")
print(embedding)
# Out:
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# File c:\just be there\hackathon\FloatChat\.venv\Lib\site-packages\langchain_google_genai\embeddings.py:227, in GoogleGenerativeAIEmbeddings.embed_documents(self, texts, batch_size, task_type, titles, output_dimensionality)
#     226 try:
# --> 227     result = self.client.batch_embed_contents(
#     228         BatchEmbedContentsRequest(requests=requests, model=self.model)
#     229     )
#     230 except Exception as e:
#
# File c:\just be there\hackathon\FloatChat\.venv\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:1392, in GenerativeServiceClient.batch_embed_contents(self, request, model, requests, retry, timeout, metadata)
#    1391 # Send the request.
# -> 1392 response = rpc(
#    1393     request,
#    1394     retry=retry,
#    1395     timeout=timeout,
# ...
