# %% [markdown]
# Create a test sql database from titanic dataset.

# %% [markdown]
# https://python.langchain.com/docs/use_cases/sql/csv/

# %%
import pandas as pd
from pyprojroot import here

# %%
df = pd.read_csv(here("data/for_upload/ocean_1.csv"))
print(df.shape)
print(df.columns.tolist())
display(df.head(3))
# Out:
# (1793, 13)
# ['id', 'type', 'cast_id', 'latitude', 'longitude', 'date', 'time', 'depth', 'temperature', 'salinity', 'pressure', 'dissolved_oxygen', 'region']
#                                        id      type  \
# 0  CTD_Southern_Indian_Ocean_1_20240317_1  CTD_Cast
# 1  CTD_Southern_Indian_Ocean_1_20240317_2  CTD_Cast
# 2  CTD_Southern_Indian_Ocean_1_20240317_3  CTD_Cast
#
#                                 cast_id  latitude  longitude        date  \
# 0  CTD_Southern_Indian_Ocean_1_20240317  -29.4225    80.3244  2024-03-17
# 1  CTD_Southern_Indian_Ocean_1_20240317  -29.4225    80.3244  2024-03-17
# 2  CTD_Southern_Indian_Ocean_1_20240317  -29.4225    80.3244  2024-03-17
#
#        time  depth  temperature  salinity  pressure  dissolved_oxygen  \
# 0  02:11:34    0.0       28.534    34.930      0.99              6.97
# 1  02:11:34   92.4       19.654    34.476     10.22              5.78
# 2  02:11:34  297.1        9.895    34.671     30.70              4.45
#
#                   region
# 0  Southern Indian Ocean
# 1  Southern Indian Ocean
# 2  Southern Indian Ocean

# %% [markdown]
# ### **SQL**
#
# Using SQL to interact with CSV data is the recommended approach because it is easier to limit permissions and sanitize queries than with arbitrary Python.
#
# Most SQL databases make it easy to load a CSV file in as a table (DuckDB, SQLite, etc.). Once you’ve done this you can use all of the chain and agent-creating techniques outlined in the SQL use case guide. Here’s a quick example of how we might do this with SQLite:

# %%
from langchain_community.utilities import SQLDatabase
from sqlalchemy import create_engine
db_path = str(here("data")) + "/test_sqldb.db"
db_path = f"sqlite:///{db_path}"

engine = create_engine(db_path)
# df.to_sql("titanic", engine, index=False)
df.to_sql("ocean_1", engine, index=False)
# Out:
# 1793

# %% [markdown]
# For multiple csv files, we can create a sql with multiple tables:
# ```
# df1.to_sql("csv1_name", engine, index=False)
# df2.to_sql("csv2_name", engine, index=False)
# ```

# %%
db = SQLDatabase(engine=engine)
print(db.dialect)
print(db.get_usable_table_names())
db.run("SELECT * FROM ocean_1 WHERE temperature < 2;")
# Out:
# sqlite
# ['ocean_1', 'titanic']
# "[('CTD_Southern_Indian_Ocean_1_20240317_8', 'CTD_Cast', 'CTD_Southern_Indian_Ocean_1_20240317', -29.4225, 80.3244, '2024-03-17', '02:11:34', 1028.4, 1.71, 34.794, 103.85, 2.64, 'Southern Indian Ocean'), ('CTD_Southern_Indian_Ocean_1_20240317_11', 'CTD_Cast', 'CTD_Southern_Indian_Ocean_1_20240317', -29.4225, 80.3244, '2024-03-17', '02:11:34', 1418.4, 1.91, 34.795, 142.8, 2.02, 'Southern Indian Ocean'), ('CTD_Southern_Indian_Ocean_1_20240317_13', 'CTD_Cast', 'CTD_Southern_Indian_Ocean_1_20240317', -29.4225, 80.3244, '2024-03-17', '02:11:34', 1304.3, 1.612, 34.907, 131.41, 2.28, 'Southern Indian Ocean'), ('CTD_Southern_Indian_Ocean_1_20240317_15', 'CTD_Cast', 'CTD_Southern_Indian_Ocean_1_20240317', -29.4225, 80.3244, '2024-03-17', '02:11:34', 1669.3, 1.991, 34.905, 167.93, 2.14, 'Southern Indian Ocean'), ('CTD_Southern_Indian_Ocean_1_20240317_16', 'CTD_Cast', 'CTD_Southern_Indian_Ocean_1_20240317', -29.4225, 80.3244, '2024-03-17', '02:11:34', 1765.6, 1.558, 34.902, 177.58, 2.06, 'Southern Indian Ocean'), ('CTD_Southern_Indian_Ocean_1_20240317_18', 'CTD_Cast', 'CTD_Southern_Indian_Ocean_1_20240317', -29.4225, 80.3244, '2024-03-17', '02:11:34', 1028.7, 1.657, 34.614, 103.89, 2.1, 'Southern Indian Ocean'), ('CTD_Southern_Indian_Ocean_2_20240424_14', 'CTD_Cast', 'CTD_Southern_Indian_Ocean_2_20240424', -15.513, 80.0752, '2024-04-24', '10:34:10', 1256.3, 1.951, 34.711, 126.59, 2.56, 'Southern Indian Ocean'), ('CTD_Southern_Indian_Ocean_2_20240424_17', 'CTD_Cast', 'CTD_Southern_Indian_Ocean_2_20240424', -15.513, 80.0752, '2024-04-24', '10:34:10', 1572.3, 1.593, 34.679, 158.26, 2.27, 'Southern Indian Ocean'), ('CTD_Southern_Indian_Ocean_2_20240424_19', 'CTD_Cast', 'CTD_Southern_Indian_Ocean_2_20240424', -15.513, 80.0752, '2024-04-24', '10:34:10', 2673.9, 1.841, 34.938, 268.42, 2.31, 'Southern Indian Ocean'), ('CTD_Central_Indian_Ocean_3_20241223_13', 'CTD_Cast', 'CTD_Central_Indian_Ocean_3_20241223', -14.8488, 86.4142, '2024-12-23', '16:31:21', 1429.6, 1.786, 34.466, 143.97, 2.91, 'Central Indian Ocean'), ('CTD_Central_Indian_Ocean_3_20241223_15', 'CTD_Cast', 'CTD_Central_Indian_Ocean_3_20241223', -14.8488, 86.4142, '2024-12-23', '16:31:21', 1243.5, 1.679, 34.548, 125.4, 2.09, 'Central Indian Ocean'), ('CTD_Central_Indian_Ocean_3_20241223_17', 'CTD_Cast', 'CTD_Central_Indian_Ocean_3_20241223', -14.8488, 86.4142, '2024-12-23', '16:31:21', 1334.4, 1.592, 34.687, 134.42, 2.83, 'Central Indian Ocean'), ('CTD_Southern_Indian_Ocean_4_20250813_16', 'CTD_Cast', 'CTD_Southern_Indian_Ocean_4_20250813', -18.7993, 56.5768, '2025-08-13', '06:41:18', 2018.2, 1.504, 34.845, 202.8, 2.27, 'Southern Indian Ocean'), ('CTD_Southern_Indian_Ocean_4_20250813_21', 'CTD_Cast', 'CTD_Southern_Indian_Ocean_4_20250813', -18.7993, 56.5768, '2025-08-13', '06:41:18', 2721.4, 1.591, 34.782, 273.18, 2.16, 'Southern Indian Ocean'), ('CTD_Southern_Indian_Ocean_4_20250813_22', 'CTD_Cast', 'CTD_Southern_Indian_Ocean_4_20250813', -18.7993, 56.5768, '2025-08-13', '06:41:18', 2302.0, 1.813, 34.464, 231.22, 2.32, 'Southern Indian Ocean'), ('CTD_Southern_Indian_Ocean_4_20250813_24', 'CTD_Cast', 'CTD_Southern_Indian_Ocean_4_20250813', -18.7993, 56.5768, '2025-08-13', '06:41:18', 2268.5, 1.564, 34.986, 227.89, 2.26, 'Southern Indian Ocean'), ('CTD_Central_Indian_Ocean_5_20240930_12', 'CTD_Cast', 'CTD_Central_Indian_Ocean_5_20240930', -6.2768, 83.3339, '2024-09-30', '02:17:13', 1560.1, 1.578, 34.904, 156.99, 2.72, 'Central Indian Ocean'), ('CTD_Central_Indian_Ocean_5_20240930_16', 'CTD_Cast', 'CTD_Central_Indian_Ocean_5_20240930', -6.2768, 83.3339, '2024-09-30', '02:17:13', 1599.3, 1.589, 34.701, 160.96, 2.37, 'Central Indian Ocean'), ('CTD_Central_Indian_Ocean_5_20240930_19', 'CTD_Cast', 'CTD_Central_Indian_Ocean_5_20240930', -6.2768, 83.3339, '2024-09-30', '02:17:13', 2393.0, 1.97, 34.531, 240.29, 2.54, 'Central Indian Ocean'), ('CTD_Equatorial_Indian_Ocean_6_20241122_10', 'CTD_Cast', 'CTD_Equatorial_Indian_Ocean_6_20241122', -4.4025, 91.3867, '2024-11-22', '11:25:56', 1144.8, 1. ...

# %% [markdown]
# **Equivalent in Pandas**

# %%
df[df["temperature"]<2]
# Out:
#                                               id      type  \
# 7         CTD_Southern_Indian_Ocean_1_20240317_8  CTD_Cast
# 10       CTD_Southern_Indian_Ocean_1_20240317_11  CTD_Cast
# 12       CTD_Southern_Indian_Ocean_1_20240317_13  CTD_Cast
# 14       CTD_Southern_Indian_Ocean_1_20240317_15  CTD_Cast
# 15       CTD_Southern_Indian_Ocean_1_20240317_16  CTD_Cast
# ...                                          ...       ...
# 1783  CTD_Equatorial_Indian_Ocean_76_20250824_15  CTD_Cast
# 1785  CTD_Equatorial_Indian_Ocean_76_20250824_17  CTD_Cast
# 1786  CTD_Equatorial_Indian_Ocean_76_20250824_18  CTD_Cast
# 1788  CTD_Equatorial_Indian_Ocean_76_20250824_20  CTD_Cast
# 1789  CTD_Equatorial_Indian_Ocean_76_20250824_21  CTD_Cast
#
#                                       cast_id  latitude  longitude  \
# 7        CTD_Southern_Indian_Ocean_1_20240317  -29.4225    80.3244
# 10       CTD_Southern_Indian_Ocean_1_20240317  -29.4225    80.3244
# 12       CTD_Southern_Indian_Ocean_1_20240317  -29.4225    80.3244
# 14       CTD_Southern_Indian_Ocean_1_20240317  -29.4225    80.3244
# 15       CTD_Southern_Indian_Ocean_1_20240317  -29.4225    80.3244
# ...                                       ...       ...        ...
# 1783  CTD_Equatorial_Indian_Ocean_76_20250824    7.8635    73.1906
# 1785  CTD_Equatorial_Indian_Ocean_76_20250824    7.8635    73.1906
# 1786  CTD_Equatorial_Indian_Ocean_76_20250824    7.8635    73.1906
# 1788  CTD_Equatorial_Indian_Ocean_76_20250824    7.8635    73.1906
# 1789  CTD_Equatorial_Indian_Ocean_76_20250824    7.8635    73.1906
#
#             date      time   depth  temperature  salinity  pressure  \
# 7     2024-03-17  02:11:34  1028.4        1.710    34.794    103.85
# 10    2024-03-17  02:11:34  1418.4        1.910    34.795    142.80
# 12    2024-03-17  02:11:34  1304.3        1.612    34.907    131.41
# 14    2024-03-17  02:11:34  1669.3        1.991    34.905    167.93
# 15    2024-03-17  02:11:34  1765.6        1.558    34.902    177.58
# ...          ...       ...     ...          ...       ...       ...
# 1783  2025-08-24  13:24:56  2073.6        1.508    34.914    208.33
# 1785  2025-08-24  13:24:56  1418.6        1.689    34.808    142.82
# 1786  2025-08-24  13:24:56  1607.6        1.679    34.603    161.77
# 1788  2025-08-24  13:24:56  1632.3        1.792    34.766    164.21
# 1789  2025-08-24  13:24:56  2773.3        1.640    34.734    278.32
#
#       dissolved_oxygen                   region
# 7                 2.64    Southern Indian Ocean
# 10                2.02    Southern Indian Ocean
# 12                2.28    Southern Indian Ocean
# 14                2.14    Southern Indian Ocean
# 15                2.06    Southern Indian Ocean
# ...                ...                      ...
# 1783              2.94  Equatorial Indian Ocean
# 1785              2.24  Equatorial Indian Ocean
# 1786              2.91  Equatorial Indian Ocean
# 1788              2.45  Equatorial Indian Ocean
# 1789              2.46  Equatorial Indian Ocean
#
# [468 rows x 13 columns]

# %% [markdown]
# ### **Create an agent to interact with the Database**

# %%
import os
from dotenv import load_dotenv
import warnings
warnings.filterwarnings("ignore")
print("Environment variables are loaded:", load_dotenv())
print("test by reading a variable:", os.getenv("GOOGLE_API_KEY"))
# Out:
# Environment variables are loaded: True
# test by reading a variable: AIzaSyDjRyVPfWz2z4U7hnsORVyQwV3o_6U-uXc

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

google_api_key = os.environ["GOOGLE_API_KEY"]
llm = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash",  
    google_api_key=google_api_key,
    temperature=0.0
)

# %%
from langchain_community.agent_toolkits import create_sql_agent
agent_executor = create_sql_agent(llm, db=db, agent_type="tool-calling", verbose=True)

# %%
agent_executor.invoke({"input": "what is the average value of depth"})
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_list_tables` with `{}`
#
#
# ocean_1, titanic
# Invoking: `sql_db_schema` with `{'table_names': 'ocean_1'}`
#
#
#
# CREATE TABLE ocean_1 (
# 	id TEXT,
# 	type TEXT,
# 	cast_id TEXT,
# 	latitude FLOAT,
# 	longitude FLOAT,
# 	date TEXT,
# 	time TEXT,
# 	depth FLOAT,
# 	temperature FLOAT,
# 	salinity FLOAT,
# 	pressure FLOAT,
# 	dissolved_oxygen FLOAT,
# 	region TEXT
# )
#
# /*
# 3 rows from ocean_1 table:
# id	type	cast_id	latitude	longitude	date	time	depth	temperature	salinity	pressure	dissolved_oxygen	region
# CTD_Southern_Indian_Ocean_1_20240317_1	CTD_Cast	CTD_Southern_Indian_Ocean_1_20240317	-29.4225	80.3244	2024-03-17	02:11:34	0.0	28.534	34.93	0.99	6.97	Southern Indian Ocean
# CTD_Southern_Indian_Ocean_1_20240317_2	CTD_Cast	CTD_Southern_Indian_Ocean_1_20240317	-29.4225	80.3244	2024-03-17	02:11:34	92.4	19.654	34.476	10.22	5.78	Southern Indian Ocean
# CTD_Southern_Indian_Ocean_1_20240317_3	CTD_Cast	CTD_Southern_Indian_Ocean_1_20240317	-29.4225	80.3244	2024-03-17	02:11:34	297.1	9.895	34.671	30.7	4.45	Southern Indian Ocean
# */
# Invoking: `sql_db_query` with `{'query': 'SELECT AVG(depth) FROM ocean_1'}`
#
#
# [(1213.533017289458,)]The average depth is 1213.53 meters.
#
#
# > Finished chain.
# {'input': 'what is the average value of depth',
#  'output': 'The average depth is 1213.53 meters.\n'}
